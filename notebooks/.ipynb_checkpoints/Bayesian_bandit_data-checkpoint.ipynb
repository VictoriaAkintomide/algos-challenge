# %%
import json
import requests
import pandas as pd

url = 'http://bayesian-bandit.adludio.com/'

r = requests.post(url +'dump_bandit_data', json={'item_group_id_list': ['uwyvrja'] } )
parsed = json.loads(r.content)
df = pd.DataFrame(parsed['bandit_data']).sort_values('date')
df
# Out:
#         id  item_id item_group_id        date           created_at  \
# 0    10343  158d2i4       uwyvrja  2020-09-23  2021-02-01 18:54:32
# 171  10344  f755tsf       uwyvrja  2020-09-23  2021-02-01 18:54:32
# 62   10340  52nuiyr       uwyvrja  2020-09-23  2021-02-01 18:54:31
# 279  10341  i4li3e7       uwyvrja  2020-09-23  2021-02-01 18:54:31
# 324  10338  pwix0yl       uwyvrja  2020-09-23  2021-02-01 18:54:31
# ..     ...      ...           ...         ...                  ...
# 169  10718  f755tsf       uwyvrja  2020-11-15  2021-02-01 18:55:02
# 271  10720  i4li3e7       uwyvrja  2020-11-15  2021-02-01 18:55:03
# 47   10716  158d2i4       uwyvrja  2020-11-15  2021-02-01 18:55:02
# 157  10722  cbr81rt       uwyvrja  2020-11-15  2021-02-01 18:55:03
# 57   10717  52nuiyr       uwyvrja  2020-11-15  2021-02-01 18:55:02
#
#      num_success  num_trials  num_engagements  num_impressions  \
# 0           1454        8431             1454             8431
# ...
